# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## Week 3 Portion

# %% [markdown]
# ### 1. Get data and clean

# %%
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
#!conda install -c conda-forge geocoder --yes
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2020.4.5.2 |       hecda079_0         147 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2020.4.5.2         |   py36h9f0ad1d_0         152 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.2-hecda079_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.2-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# ca-certificates-2020 | 147 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# certifi-2020.4.5.2   | 152 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import numpy as np
import pandas as pd
import json # library to handle JSON files

import requests
from bs4 import BeautifulSoup

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#import geocoder # import geocoder

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

results = pd.read_html(url)
df = results[0]
df_toronto = df[df['Neighborhood']!="Not assigned"].reset_index(drop=True)
print(df_toronto.shape)
# Out:
# (103, 3)

# %% [markdown]
# ### 2. Get latitude and longitude

# %%
# Try obtaining coordinates using geocoder-Google
#latitude = np.zeros(df_toronto.shape[0])
#longitude = np.zeros(df_toronto.shape[0])
#for i, postal_code in enumerate(df_toronto['Postal Code']):
#    print(i, postal_code)
#    # initialize your variable to None
#    lat_lng_coords = None

#    # loop until you get the coordinates
#    while(lat_lng_coords is None):
#        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#        print(g)
#        lat_lng_coords = g.latlng

#    latitude[i] = lat_lng_coords[0]
#    longitude[i] = lat_lng_coords[1]

# %%
# Obtain coordinates from the csv file
# !wget -O Geospatial_Coordinates.csv http://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
df_geo = pd.read_csv("Geospatial_Coordinates.csv")
df_toronto.sort_values(by=['Postal Code'],inplace=True)
df_geo.sort_values(by=['Postal Code'],inplace=True)
df_toronto['Latitude'] = df_geo['Latitude']
df_toronto['Longitude'] = df_geo['Longitude']
df_toronto.reset_index(inplace=True)
df_toronto.drop(columns=['index'],inplace=True)
df_toronto
# Out:
# --2020-06-17 20:46:31--  http://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Resolving cocl.us (cocl.us)... 158.85.108.86, 169.48.113.194, 158.85.108.83
# Connecting to cocl.us (cocl.us)|158.85.108.86|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv [following]
# --2020-06-17 20:46:32--  https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Connecting to cocl.us (cocl.us)|158.85.108.86|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 20:46:32--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 20:46:33--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-17 20:46:33--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!PBvmKCUQwHD2oSk6FrMTk5Vn8AW0XVQ6Nk9ngxkTpGUjLJlK-OYkLpJmC_zhJXtsUTmyEqnPZMo1x8gw9Boi9vj2q-1dcRMp5cbyY0J2JhvC_fiDoXqBqmnpuBLqtGu5iE2n1LC5-mTBN5-9c0PjGUkndh08dtdgV9EirFzzHlWhe7fNKh9DSAnRMod6kNdqjuFw-t-F7g4bKySNbsdmg6H8KvzoDprz41eVdPEmHRqOHzhuzGNVyuviI4Sy5K6F43NF4I-nXQUB8t-qdaYUBwQS5kJRB8KpUVfe8STCNZI60LYOy7ny1DomiYT0-4s_LX38luiymBMVNqcOpmSWdKhsv8TCIn2BH8btUlbobSlyT985cYROgBsDCMxSTpAViAoq1yXDXbMJvcmJvxQ8SiJDYcngxkh8CHwTaVsPgxXiEaPELi-zgm4lCQJYhsNiU5IeIJz96pSUgxuUvrtQau740PaV24eoPBou_royaepnxML6BSkXgHnnZ8giR7Xk6YT_JUTtrnnu_UTRhky25-E8TJ0ompztwfTCYrJrS3i54R8T-3O_1R8sETcHDnhHkxG_5QsFZAIJTV2BgTgBGc0SmiJnIpECxfgdJKaNL7ESfDHwa5ER7bIK7Q3lQL63TRsjvi7lfIFgCkXO7z9DGc
FlPmdwVKnieBk0xLQ2hWwn8i0nbV9uvta0TxleLN1bPCLom0-mFEj3DclaRtomADfH4MIm6VvG7ylE8XB_jlP4wNDUKqemu8q3C0n3rXfI-SfMyvq1c7ZHBmr2HaeQasTyUCJRLVhW0cvYMV9JlF3CkH42cg_LbZ2xTsVFlP_jQDS7qF-40LWmrufF96-FTN0AlRm4G-EiCyVlgTGdQqnGRBj9hRqKG81W1Fe_0TXQFzz1UsJajYDwz3uVPQU-p1wCw4vObRmTBdXsz4x6ZdiEDgrVoH8d4b4VpEb3SwWTm5Bf4b-bZ8n6WN3ZO8CKSH_p6_EXl1PsUvGB9lsZKNdQ_qNszwBNHrRqqe85NE57UXcsXCvk9wYr3L-qWW370pzhfx3f44YhTy6i9xpV-0qlwXO_pxB1r-1URuNktRwuljXaCjurxgaXV3t6DW741WO3a4RbNeZ4L3YRTTiVGm5v1K7SdtkIDEAoLFue85SHhe7zrKXIEaAswUyt70tKkFC8FvDM0e6XeSUD5TNql6_NYackRENoDEDekq7bLLfJseMCYcWI1ZiwLZQ8XFEfSrbQExgp8d7QUJXxw4oFB5JGKhxvVgSCD_H2dHQ6zs3uz1jYKUJN1pz5M109rvf5eyBAE6WavVTBkD/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.29.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.29.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordinates.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-06-17 20:46:34 (253 MB/s) - ‘Geospatial_Coordinates.csv’ saved [2891/2891]
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A  Downtown Toronto
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.602414 -79.543484
# 102                Northwest, West Humber - Clairville  43.650943 -79.554724
#
# [103 rows x 5 columns]

# %% [markdown]
# ## 3. Cluster postal codes into Boroughs
#
# ##### Here, let's try something very simple - applying K-means to Borough encoding. It is just to check if K-means indeed successfully clusters by Boroughs. Also, it would be nice to visualize where these Boroughs are within Toronto.

# %%
nborough = len(df_toronto['Borough'].unique())
print('There are {} Boroughs.'.format(nborough))

# do one hot encoding on Boroughs
df_onehot = pd.get_dummies(df_toronto[['Borough']], prefix="", prefix_sep="")

# add the Postal Code column back to dataframe
df_onehot['Postal Code'] = df_toronto['Postal Code'] 
df_onehot.sort_index

# move the Postal Code column to the first column
fixed_columns = [df_onehot.columns[-1]] + list(df_onehot.columns[:-1])
df_onehot = df_onehot[fixed_columns]
#df_grouped = df_onehot.groupby('Postal Code').mean().reset_index()
#df_grouped.head()
# Out:
# There are 10 Boroughs.

# %%
# set number of clusters
kclusters = len(df_toronto['Borough'].unique()) # cluster into Boroughs

df_cluster = df_onehot.drop('Postal Code', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_cluster)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
df_cluster.insert(0, 'Cluster Label', kmeans.labels_)

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
#manhattan_merged = manhattan_data
#manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
#manhattan_merged.head() # check the last columns!

# %%
# create map
map_clusters = folium.Map(location=[df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean()], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_cluster['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-67d8de448aa5> in <module>
#       1 # create map
# ----> 2 map_clusters = folium.Map(location=[df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean()], zoom_start=11)
#       3
#       4 # set color scheme for the clusters
#       5 x = np.arange(kclusters)
#
# NameError: name 'folium' is not defined

# %% [markdown]
# ### 4. Learn Borough classification model using coordinates

# %%
# X = feature matrix, y = response data                                                                                                                                                                          
X = np.asarray(df_toronto[['Latitude','Longitude']])
y = np.asarray(df_toronto['Borough'].astype('category').cat.codes)

# normalize dataset                                                                                                                                                                                              
from sklearn import preprocessing
X = preprocessing.MinMaxScaler().fit(X).transform(X)
#StandardScaler().fit(X).transform(X)

# train-test split                                                                                                                                                                                               
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4 )
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

# Logistic Regression                                                                                                                                                                                           
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(solver='newton-cg', max_iter=100, multi_class='multinomial', penalty='l2', C=0.1).fit(X_train,y_train)
yhat = LR.predict(X_test)
yhat_prob = LR.predict_proba(X_test)
print(y_test == yhat)
print(np.sum(y_test == yhat)/len(y_test == yhat))

# Support Vector Machine                                                                                                                                                                                           
from sklearn import svm
clf = svm.SVC(kernel='sigmoid',gamma='auto', C=1)
clf.fit(X_train, y_train)                                                                                                                                                                                        
yhat = clf.predict(X_test)
print(y_test == yhat)
print(np.sum(y_test == yhat)/len(y_test == yhat))

# run k-means clustering
kmeans = KMeans(n_clusters=10, random_state=0).fit(X)
# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# Train set: (82, 2) (82,)
# Test set: (21, 2) (21,)
# [False False False  True False False False False  True False  True False
#  False False False  True False False False False  True]
# 0.23809523809523808
# [False False False  True False False False False  True False  True False
#  False False False  True False False False False  True]
# 0.23809523809523808
# array([4, 6, 6, 1, 4, 7, 5, 5, 0, 0, 0, 5, 0, 3, 0, 3, 9, 4, 7, 8, 5, 0,
#        0, 0, 5, 2, 4, 6, 1, 4, 8, 5, 0, 0, 2, 4, 6, 1, 1, 1, 8, 8, 5, 0,
#        0, 0, 5, 7, 3, 9, 3, 7, 7, 2, 8, 6, 1, 1, 7, 8, 8, 5, 0, 5, 0, 5,
#        3, 3, 8, 9, 7, 2, 4, 2, 1, 4, 7, 8, 0, 5, 0, 5, 0, 0, 3, 2, 3, 3,
#        9, 3, 7, 7, 7, 4, 4, 6, 0, 0, 5, 0, 0, 9, 9], dtype=int32)

# %%
# create map
map_clusters = folium.Map(location=[df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean()], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], kmeans.labels_):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %% [markdown]
# ### 5. Use Foursquare to scrape venue data

# %%
CLIENT_ID = 'M0AMS10V3MXAFMKQGK3JY3TE0SDODCNBRLBVDAUQCJPTVS5X' # your Foursquare ID
CLIENT_SECRET = 'C1PYOJOMKZEDOJN143T3IVFRH5QNMYAK5QYMWBK2BDQPYD5G' # your Foursquare Secret
VERSION = '20180604'
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: M0AMS10V3MXAFMKQGK3JY3TE0SDODCNBRLBVDAUQCJPTVS5X
# CLIENT_SECRET:C1PYOJOMKZEDOJN143T3IVFRH5QNMYAK5QYMWBK2BDQPYD5G

# %%
search_query = 'coffee'
radius = 5000 # in meters
LIMIT = 1000  # Maximum number of results to obtain
print('Querying for',search_query)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean(), VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_venues = json_normalize(venues)
df_venues = df_venues[df_venues['location.city']=='Toronto']
print(len(df_venues),'venues obtained')
df_venues.head(10)
# Out:
# Querying for coffee
# 48 venues obtained
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 4   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 6   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 7   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 8   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 9   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 10  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 11  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
#
#                           id         location.address location.cc  \
# 0   4ae33eb5f964a5203a9221e3      700 mt pleasant ave          CA
# 3   5aff3c8b89e490002ca035e3         1860 Bayview Ave          CA
# 4   4aeed74cf964a5205dd421e3          1 Pleasant Blvd          CA
# 5   4c8633a8d92ea09359ed6b72        2300 Yonge Street          CA
# 6   4bec3c4662c0c928c61ae3d4        90 Eglinton Ave E          CA
# 7   4c5783a28fe2ef3b466b303a    233 Eglinton Ave West          CA
# 8   4ad79243f964a5204c0c21e3       519 Parliament St.          CA
# 9   4ff75b7ee4b09036684f84cb           2011 Yonge St.          CA
# 10  4ea88fc7f5b9df9610511b8d  1471 Eglinton Avenue W.          CA
# 11  4c3b41985810a593cc55ba3c      10 Scrivener Square          CA
#
#    location.city location.country              location.crossStreet  \
# 0        Toronto           Canada                               NaN
# 3        Toronto           Canada                               NaN
# 4        Toronto           Canada                      at Yonge St.
# 5        Toronto           Canada                               NaN
# 6        Toronto           Canada  btwn. Yonge St. and Redpath Ave.
# 7        Toronto           Canada       Oriole Parkway and Eglinton
# 8        Toronto           Canada         btwn Carlton & Winchester
# 9        Toronto           Canada                               NaN
# 10       Toronto           Canada                     at Winona Dr.
# 11       Toronto           Canada                               NaN
#
#     location.distance                          location.formattedAddress  \
# 0                 646          [700 mt pleasant ave, Toronto ON, Canada]
# 3                1933     [1860 Bayview Ave, Toronto ON M4G 0C3, Canada]
# 4                1972  [1 Pleasant Blvd (at Yonge St.), Toronto ON, C...
# 5                 268            [2300 Yonge Street, Toronto ON, Canada]
# 6                 323  [90 Eglinton Ave E (btwn. Yonge St. and Redpat...
# 7                 709  [233 Eglinton Ave West (Oriole Parkway and Egl...
# 8                4953  [519 Parliament St. (btwn Carlton & Winchester...
# 9                 399               [2011 Yonge St., Toronto ON, Canada]
# 10               3459  [1471 Eglinton Avenue W. (at Winona Dr.), Toro...
# 11               2708          [10 Scrivener Square, Toronto ON, Canada]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 43.70602710190901...     43.706027
# 3   [{'label': 'display', 'lat': 43.71489, 'lng': ...     43.714890
# 4   [{'label': 'display', 'lat': 43.687086, 'lng':...     43.687086
# 5   [{'label': 'display', 'lat': 43.70671799326533...     43.706718
# 6   [{'label': 'display', 'lat': 43.70733914888304...     43.707339
# 7   [{'label': 'display', 'lat': 43.703966, 'lng':...     43.703966
# 8   [{'label': 'display', 'lat': 43.66529519392083...     43.665295
# 9   [{'label': 'display', 'lat': 43.70102127431561...     43.701021
# 10  [{'label': 'display', 'lat': 43.69185299317205...     43.691853
# 11  [{'label': 'display', 'lat': 43.68070416529024...     43.680704
#
#     location.lng location.neighborhood location.postalCode location.state  \
# 0     -79.389369                   NaN                 NaN             ON
# 3     -79.377780                   NaN             M4G 0C3             ON
# 4     -79.393541                   NaN                 NaN             ON
# 5     -79.398766                   NaN                 NaN             ON
# 6     -79.395770                   NaN             M4P 1A6             ON
# 7     -79.405920                   NaN                 NaN             ON
# 8     -79.368335                   NaN             M4X 1P3             ON
# 9     -79.397027                   NaN                 NaN             ON
# 10    -79.436344                   NaN             M6E 2G6             ON
# 11    -79.390905                   NaN                 NaN             ON
#
#                       name    referralId
# 0   Timothy's World Coffee  v-1592429354
# 3           WFM Coffee Bar  v-1592429354
# 4   Timothy's World Coffee  v-1592429354
# 5   Timothy's World Coffee  v-1592429354
# 6   Timothy's World Coffee  v-1592429354
# 7              Coffee Time  v-1592429354
# 8           Jetfuel Coffee  v-1592429354
# 9    Rachel's Coffee House  v-1592429354
# 10      Coffee Time Donuts  v-1592429354
# 11  Timothy's World Coffee  v-1592429354

# %%
# create map
map_clusters = folium.Map(location=[df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean()], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, name in zip(df_venues['location.lat'], df_venues['location.lng'], df_venues['name']):
    label = folium.Popup(str(name), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-05e05ebb9b82> in <module>
#       1 # create map
# ----> 2 map_clusters = folium.Map(location=[df_toronto['Latitude'].mean(), df_toronto['Longitude'].mean()], zoom_start=11)
#       3
#       4 # set color scheme for the clusters
#       5 x = np.arange(kclusters)
#
# NameError: name 'folium' is not defined

# %%
for venue_id, lat, lon, name in zip(df_venues['id'],df_venues['location.lat'],df_venues['location.lng'],df_venues['name']):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

    result = requests.get(url).json()
    print(result)
    try:
        print(name, result['response']['venue']['rating'])
    except:
        print(name, '- This venue has not been rated yet.')
# Out:
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8339b1cac0001be422d4'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82f8fb34b5001b01e415'}, 'response': {}}
# WFM Coffee Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea828fa2e538001be57472'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8390542890001bd83ae4'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea838e216785001b03097f'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea822995feaf001b1d564c'}, 'response': {}}
# Coffee Time - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83a06001fe001bf3596e'}, 'response': {}}
# Jetfuel Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83441e152c001be1b05b'}, 'response': {}}
# Rachel's Coffee House - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea817a29ce6a001b57b7ce'}, 'response': {}}
# Rooster Coffee House - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea833d78a484001c1c7397'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83451e152c001be1b192'}, 'response': {}}
# Coffee Time Donuts - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8305b9a389001b14a951'}, 'response': {}}
# Rooster Coffee House - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83b3be61c9001c6b568d'}, 'response': {}}
# Coffee Lime & Deli - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea820d006dce001b8a52d1'}, 'response': {}}
# Well And Better Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea838fc94979001b51a371'}, 'response': {}}
# At Origin Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83c6f7706a001bcb286e'}, 'response': {}}
# Coffee Pocket - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea838fc94979001b51a422'}, 'response': {}}
# Crosstown Coffee bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea835147e0d60027c97c77'}, 'response': {}}
# De Mello Palheta Coffee Roasters - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83461e152c001be1b4ff'}, 'response': {}}
# Rivet's Dolce Gusto Coffee Counter - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8389c8cff2001b631f88'}, 'response': {}}
# Coffee Culture Cafe & Eatery - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea836bedbcad001b104d84'}, 'response': {}}
# WFM Coffee Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8242211536001b6cf584'}, 'response': {}}
# The Mad Bean Coffee House - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83aa0be7b4001b5d86ea'}, 'response': {}}
# Starbucks - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82d5e826ac00216fd3e7'}, 'response': {}}
# I Deal Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea835114a126001b2fdfeb'}, 'response': {}}
# Sam James Coffee Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83c7f7706a001bcb2bfa'}, 'response': {}}
# Jimmy's Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea831f0cc1fd001bb37da3'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8393542890001bd84465'}, 'response': {}}
# Second Cup Coffee Co. featuring Pinkberry Frozen Yogurt - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea810002a17200222a75eb'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea836cc546f3001b11dc3d'}, 'response': {}}
# Canadian Barista & Coffee Academy - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8308b9a389001b14b0d0'}, 'response': {}}
# T.A.N. Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82d6e826ac00216fd6b9'}, 'response': {}}
# Sakawa Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8210006dce001b8a5ab2'}, 'response': {}}
# Second Cup Coffee Co. featuring Pinkberry Frozen Yogurt - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83210cc1fd001bb380bf'}, 'response': {}}
# Timothy's World Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8293a2e538001be58165'}, 'response': {}}
# Super Jet International Coffee Shop - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea835314a126001b2fe4c0'}, 'response': {}}
# Creeds Coffee Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83a2949393001b636e48'}, 'response': {}}
# Aroma Espresso Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea8272b4b684001bca26f3'}, 'response': {}}
# Coffee Time - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea835f83525f001b196b48'}, 'response': {}}
# Coffee Lunar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea833569babe001b7ca108'}, 'response': {}}
# Coffee Island - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82fdfb34b5001b01f42d'}, 'response': {}}
# Coffee Public - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83a2949393001b637028'}, 'response': {}}
# Coffee time - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea81e1660a9f001b9392b6'}, 'response': {}}
# Second Cup Coffee Co. featuring Pinkberry Frozen Yogurt - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea81d4bae9a2001bbf4be2'}, 'response': {}}
# Neo Coffee Bar - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea834b6d8c5600282b29b8'}, 'response': {}}
# Coffee Time - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea83caf7706a001bcb345c'}, 'response': {}}
# Krave Coffee - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82d8e826ac00216fdcf1'}, 'response': {}}
# Coffee Place - This venue has not been rated yet.
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eea82d8e826ac00216fdd5a'}, 'response': {}}
# Intergalactic Coffee - This venue has not been rated yet.
